# %% [markdown]
# # Task 1

# %% [markdown]
# We are demonstrating the use of a **bold** and *italics* text (and the use of a title above).

# %% [markdown]
# # Task 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import os

# %%
from Scripts.functions import load_and_process

# %% [markdown]
# Our Method chaining 1 and 2 (load_and_process)- We renamed columns, dropped columns, calculated, assigned causal ratios, calculated an average temperature and made the columns more descriptive)
#
# It can be found in the 'functions.py' folder found in 'Scripts'

# %%
df=load_and_process('../Data/Raw/hour.csv')

# %%
df
# Out:
#        Instant        Date  Season     Month  Hour  Holiday? Day of Week  \
# 0            1  2011-01-01  Winter   January     0     False    Saturday
# 1            2  2011-01-01  Winter   January     1     False    Saturday
# 2            3  2011-01-01  Winter   January     2     False    Saturday
# 3            4  2011-01-01  Winter   January     3     False    Saturday
# 4            5  2011-01-01  Winter   January     4     False    Saturday
# ...        ...         ...     ...       ...   ...       ...         ...
# 17374    17375  2012-12-31  Winter  December    19     False      Monday
# 17375    17376  2012-12-31  Winter  December    20     False      Monday
# 17376    17377  2012-12-31  Winter  December    21     False      Monday
# 17377    17378  2012-12-31  Winter  December    22     False      Monday
# 17378    17379  2012-12-31  Winter  December    23     False      Monday
#
#        Workday? Weather Situation  Temperature  Feeling Temperature  \
# 0         False             Sunny         9.84               14.395
# 1         False             Sunny         9.02               13.635
# 2         False             Sunny         9.02               13.635
# 3         False             Sunny         9.84               14.395
# 4         False             Sunny         9.84               14.395
# ...         ...               ...          ...                  ...
# 17374      True            Cloudy        10.66               12.880
# 17375      True            Cloudy        10.66               12.880
# 17376      True             Sunny        10.66               12.880
# 17377      True             Sunny        10.66               13.635
# 17378      True             Sunny        10.66               13.635
#
#        Casual Users  Registered User  Total Users  Casual_Ratio  \
# 0                 3               13           16      0.187500
# 1                 8               32           40      0.200000
# 2                 5               27           32      0.156250
# 3                 3               10           13      0.230769
# 4                 0                1            1      0.000000
# ...             ...              ...          ...           ...
# 17374            11              108          119      0.092437
# 17375             8               81           89      0.089888
# 17376             7               83           90      0.077778
# 17377            13               48           61      0.213115
# 17378            12               37           49      0.244898
#
#        Average_temperature  Wind Speed
# 0                  0.26395      0.0000
# 1                  0.24635      0.0000
# 2                  0.24635      0.0000
# 3                  0.26395      0.0000
# 4                  0.26395      0.0000
# ...                    ...         ...
# 17374              0.25880     11.0014
# 17375              0.25880     11.0014
# 17376              0.25880     11.0014
# 17377              0.26635      8.9981
# 17378              0.26635      8.9981
#
# [17379 rows x 17 columns]

# %%
df.describe(exclude=np.number).T
# Out:
#                    count unique         top   freq
# Date               17379    731  2012-06-01     24
# Season             17379      4      Summer   4496
# Month              17379     12        July   1488
# Holiday?           17379      2       False  16879
# Day of Week        17379      7    Saturday   2512
# Workday?           17379      2        True  11865
# Weather Situation  17379      4       Sunny  11413

# %% [markdown]
# # Task 4 - EDA (Medha)

# %%
graph=sns.catplot(data=df, y= "Total Users",x= "Weather Situation", hue= "Day of Week",col="Season")
#mention that 0 is sunday.

# %% [markdown]
# The four graphs show the total amount of bicycle users per season as well as an analysis of the weather situation. There seems to be a direct correlation between the weather situation and the amount of users. Unsurprisingly, there seems to be little to no bicycle riders when there is weather precipitation. There also seems to be less bicycle riders during winter as compared to the three other seasons (even when it is sunny).

# %%
graph_1=sns.catplot(data=df, y= "Total Users",x= "Holiday?", hue= "Day of Week",col="Season")

# %% [markdown]
# There are four graphs, each representing different seasons. I am trying to investigate whether there is a correlation between total users and holidays per season. It is interesting to see that people consistently, across all seasons, use their bicycles way less during holidays.

# %%
df.plot(kind='scatter',x='Season', y='Total Users')
# Out:
# <AxesSubplot:xlabel='Season', ylabel='Total Users'>

# %% [markdown]
# When analyzing the relationship between total Users and Season directly (without any other variables), it is now clearer that while summer and fall both reach a peak(around 1000 as demonstrated by the graph), bicycles are used way less during winter (arounf 800-850, as shown by the graph).

# %%
sns.displot(data=df, x = "Total Users", bins=18, hue = "Holiday?", multiple="stack")

plt.show()

# %% [markdown]
# It is now clearer that there is a direct relationship between total users and holidays. Bicycles are more frequently used when there are no holidays.

# %%
graph_1=sns.catplot(data=df, y= "Total Users",x= "Workday?", hue= "Day of Week",col="Season")

# %% [markdown]
# Now this is interesting because while we see the same tendency as above, that there are less users during winter, we can also see that the differences between workday and not workday is smaller than holiday and not holiday, for the same period. I thought that there still would have been a big difference since there was a big difference betweeb holiday and not a holiday

# %%
sns.displot(data=df, x = "Total Users", bins=18, hue = "Month",multiple="stack")

# %% [markdown]
# The histogram below shows that there are way less bicycle users during November and December.

# %%
sns.pairplot(data=df.select_dtypes(include='number'), 
             corner=True)

# %%
df.describe(exclude=np.object).T
# Out:
#                      count unique    top   freq      mean       std   min  \
# Instant              17379    NaN    NaN    NaN      8690   5017.03     1
# Hour                 17379    NaN    NaN    NaN   11.5468   6.91441     0
# Holiday?             17379      2  False  16879       NaN       NaN   NaN
# Workday?             17379      2   True  11865       NaN       NaN   NaN
# Temperature          17379    NaN    NaN    NaN   20.3765    7.8948  0.82
# Feeling Temperature  17379    NaN    NaN    NaN   23.7888   8.59251     0
# Casual Users         17379    NaN    NaN    NaN   35.6762    49.305     0
# Registered User      17379    NaN    NaN    NaN   153.787   151.357     0
# Total Users          17379    NaN    NaN    NaN   189.463   181.388     1
# Casual_Ratio         17379    NaN    NaN    NaN  0.172143  0.136557     0
# Average_temperature  17379    NaN    NaN    NaN  0.486381  0.181643  0.01
# Wind Speed           17379    NaN    NaN    NaN   12.7365    8.1968     0
#
#                            25%       50%       75%      max
# Instant                 4345.5      8690   13034.5    17379
# Hour                         6        12        18       23
# Holiday?                   NaN       NaN       NaN      NaN
# Workday?                   NaN       NaN       NaN      NaN
# Temperature              13.94      20.5     27.06       41
# Feeling Temperature     16.665     24.24     31.06       50
# Casual Users                 4        17        48      367
# Registered User             34       115       220      886
# Total Users                 40       142       281      977
# Casual_Ratio         0.0634921  0.146893  0.253731        1
# Average_temperature     0.3303    0.4924    0.6306     0.98
# Wind Speed              7.0015    12.998   16.9979  56.9969

# %% [markdown]
# This gives me useful statistics to be able to interprete data. For example from this table, we can see that the mean hour of use is 11.5 hours and that there was a maximun of 977 total users recorded.

# %%
sns.countplot(x='Holiday?', data=df)
sns.set(rc={'figure.figsize':(11.7,6.27)})

# %% [markdown]
# This shows the number of occurences holidays. The graph demonstrates that there are way less holidays than working weekdays. This is important since we found that people tend to not use their bicycles a lot during holidays.

# %% [markdown]
# Exploring different dataset possibilities

# %%
sns.countplot(x='Average_temperature', data=df)
sns.set(rc={'figure.figsize':(11.7,6.27)})

# %% [markdown]
# Show counts of Average_temperature which is the average between Feeling temperature and Temperature

# %% [markdown]
# # Task 4 - Olivia

# %%
sns.countplot(data=df, y= "Season", palette= 'pastel', order= df['Season'].value_counts().index[:], hue= 'Weather Situation')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Season'>

# %% [markdown]
# Interestingly, the general ratio of the different weather situations did not change drastically beetween the seasons, and there were many sunny days - it must be beautiful in DC all year round!

# %%
sns.countplot(data=df, y= ("Total Users"), palette= 'pastel', order= df['Total Users'].value_counts().index[:], hue= 'Day of Week')

plt.show()

# %% [markdown]
# From this plot, it is evident that the count of total users is very high on Tuesdays, and Mondays. There are also a fair amount of users on the weekends (Saturday and Sunday).

# %%
sns.countplot(data=df, y= ("Casual Users"), palette= 'pastel', order= df['Casual Users'].value_counts().index[:], hue= 'Holiday?')

plt.show()

# %%
sns.countplot(data=df, y= ("Registered User"), palette= 'pastel', order= df['Registered User'].value_counts().index[:], hue= 'Holiday?')

plt.show()

# %%
sns.displot(data=df, x = "Total Users", bins=18, hue = "Season", multiple="stack")

plt.show()

# %% [markdown]
# The histogram shows that the count of total users is higher for a smaller amount of users.

# %%
sns.displot(data=df, x = "Casual Users", bins=18, hue = "Holiday?", multiple="stack")

plt.show()

# %%
sns.displot(data=df, x = "Registered User", bins=18, hue = "Holiday?", multiple="stack")

plt.show()

# %% [markdown]
# # Task 5 - Analysis

# %% [markdown]
# **Research Questions:**
#
# 1. What is the relationship between day of the week, and number of casual vs. registered users? Are there more registered users on weekdays, and casual users on weekends?
#
# 2. Does weather affect the total number of users?
#
# 3. Is there a spike in number of users on holidays?

# %% [markdown]
# 1. What is the relationship between day of the week, and number of casual vs. registered users? Are there more registered users on weekdays, and casual users on weekends?

# %%
sns.stripplot(data=df, x='Day of Week', y='Casual Users')
# Out:
# <AxesSubplot:xlabel='Day of Week', ylabel='Casual Users'>

# %%
sns.stripplot(data=df,x='Workday?', y='Casual Users')
# Out:
# <AxesSubplot:xlabel='Workday?', ylabel='Casual Users'>

# %%
sns.stripplot(data=df,x='Day of Week', y='Registered User')
# Out:
# <AxesSubplot:xlabel='Day of Week', ylabel='Registered User'>

# %%
sns.stripplot(data=df,x='Workday?', y='Casual Users')
# Out:
# <AxesSubplot:xlabel='Workday?', ylabel='Casual Users'>

# %%
sns.displot(df, x="Casual Users", hue="Day of Week", kind="kde")

# %%
sns.displot(df, x="Casual Users", hue="Workday?", kind="kde")

# %% [markdown]
# #There are many more casual users of weekdays than non-weekdays, according to this plot.

# %%
sns.displot(df, x="Registered User", hue="Day of Week", kind="kde")

# %% [markdown]
# There are a lot of registered users on Saturday and Sunday.

# %%
sns.displot(df, x="Registered User", hue="Workday?", kind="kde")

# %% [markdown]
# There seems to be more registered users on non-workdays, however this is likely becuase there is many more workdays than non-workdays.

# %% [markdown]
# - From the plots above, it is evident that there is an increase in both casual and registered users on the Saturdays and Sundays, compared to Monday-Friday.
#
# - Interestingly, there seem to be a higher count of both casual and registered users on workdays, compared to non-workdays.
#
# - There also seems to be a higher proportion of casual users on workdays to weekends, compared to registered users.
#
# - When we look at the days individually, the highest count of users on Saturday and Sunday for both casual and registered users, but when the number of users is considered in terms of workdays, there are many more users on workdays than non-workdays. What is causing these seemingly contradictory results? The fact that there are many more weekdays than weekends! It is biased to compare the total count of registered and casual users on workdays vs. non-workdays for this reason.
#
# - Essentially, we can conlcude that there are a higher number of both casual and registered users PER DAY on weekend days as opposed to work days.

# %% [markdown]
# 2. Does weather affect the total number of users?

# %%
sns.displot(data=df, x= ("Total Users"), hue= 'Weather Situation',multiple='stack')

plt.show()

# %%
sns.displot(df, x="Total Users", hue="Weather Situation", kind="kde")

# %% [markdown]
# Evidently, there are many more users on sunny days, followed by cloudy days, with fewer users on light or heavy precipitation days.

# %% [markdown]
# 3. Is there a spike in number of users on holidays?

# %%
sns.displot(df, x="Total Users", hue="Holiday?", kind="kde")

# %% [markdown]
# This plot shows that there are many more users on non-holidays, but does does not provide any insight into relative amounts, so it is not useful.

# %%
df2 = df[df['Holiday?']==True]
df3 = df[df['Holiday?']==False]

# %%
df2['Total Users'].mean()
# Out:
# 156.87

# %%
df3['Total Users'].mean()
# Out:
# 190.4285798921737

# %% [markdown]
# The average value of users in an hour is slightly lower on holidays than on non-holidays.
